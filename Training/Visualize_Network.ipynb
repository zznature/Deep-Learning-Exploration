# %% [markdown]
# # Visualize Network
# 一般来说，netron 和 hiddenlayer 提供的可视化效果较好，而 Graphviz 和 torchviz 则更为轻量级和可定制。

# %% [markdown]
# ## 1. netron

# %%
import torch
import torch.nn as nn
import netron

class Cifar10CnnModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 64 x 16 x 16

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 128 x 8 x 8

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 256 x 4 x 4

            nn.Flatten(), 
            nn.Linear(256*4*4, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 10))
        
    def forward(self, xb):
        return self.network(xb)

model = Cifar10CnnModel()
# 假设你的模型实例名为 model
torch.onnx.export(model, torch.randn(1, 3, 32, 32), "model.onnx")
netron.start("model.onnx")
# Out:
# Serving 'model.onnx' at http://localhost:8080
# ('localhost', 8080)

# %% [markdown]
# ## hiddenlayer

# %%
import hiddenlayer as hl
import torch
import torch.nn as nn

class Cifar10CnnModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 64 x 16 x 16

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 128 x 8 x 8

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 256 x 4 x 4

            nn.Flatten(), 
            nn.Linear(256*4*4, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 10))
        
    def forward(self, xb):
        return self.network(xb)

model = Cifar10CnnModel()
# 假设你的模型实例名为 model
graph = hl.build_graph(model, torch.zeros([1, 3, 32, 32]))
graph.theme = hl.graph.THEMES["blue"].copy()
graph.save("model_architecture.png", format="png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 39
#      37 model = Cifar10CnnModel()
#      38 # 假设你的模型实例名为 model
# ---> 39 graph = hl.build_graph(model, torch.zeros([1, 3, 32, 32]))
#      40 graph.theme = hl.graph.THEMES["blue"].copy()
#      41 graph.save("model_architecture.png", format="png")
#
# File c:\Users\zhouz\anaconda3\envs\prune_llm\lib\site-packages\hiddenlayer\graph.py:143, in build_graph(model, args, input_names, transforms, framework_transforms)
#     141     from .pytorch_builder import import_graph, FRAMEWORK_TRANSFORMS
#     142     assert args is not None, "Argument args must be provided for Pytorch models."
# --> 143     import_graph(g, model, args)
#     144 elif framework == "tensorflow":
#     145     from .tf_builder import import_graph, FRAMEWORK_TRANSFORMS
#
# File c:\Users\zhouz\anaconda3\envs\prune_llm\lib\site-packages\hiddenlayer\pytorch_builder.py:71, in import_graph(hl_graph, model, args, input_names, verbose)
#      66 def import_graph(hl_graph, model, args, input_names=None, verbose=False):
#      67     # TODO: add input names to graph
#      68
#      69     # Run the Pytorch graph to get a trace and generate a graph from it
#      70     trace, out = torch.jit._get_trace_graph(model, args)
# ---> 71     torch_graph = torch.onnx._optimize_trace(trace, torch.onnx.OperatorExportTypes.ONNX)
#      73     # Dump list of nodes (DEBUG only)
#      74     if verbose:
#
# AttributeError: module 'torch.onnx' has no attribute '_optimize_trace'

# %% [markdown]
# ## `torchview`

# %%
import torch
import torch.nn as nn

class Cifar10CnnModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 64 x 16 x 16

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 128 x 8 x 8

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 256 x 4 x 4

            nn.Flatten(), 
            nn.Linear(256*4*4, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 10))
        
    def forward(self, xb):
        return self.network(xb)

model = Cifar10CnnModel()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\zhouz\AppData\Local\Temp\ipykernel_34080\3449482318.py", line 36, in <module>
#     model = Cifar10CnnModel()
#   File "C:\Users\zhouz\AppData\Local\Temp\ipykernel_34080\3449482318.py", line 8, in __init__
#     nn.Conv2d(3, 32, kernel_size=3, padding=1),
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\torch\nn\modules\conv.py", line 447, in __init__
#     super().__init__(
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\torch\nn\modules\conv.py", line 141, in __init__
#     self.reset_parameters()
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\torch\nn\modules\conv.py", line 147, in reset_parameters
#     init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#   File "c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\torch\nn\init.py", line 459, in kaiming_uniform_
#     return tensor.uniform_(-bound, bound, generator=generator)
# c:\Users\zhouz\anaconda3\envs\deeplearning\Lib\site-packages\torch\nn\init.py:459: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:84.)
#   return tensor.uniform_(-bound, bound, generator=generator)

# %%
# import graphviz
# graphviz.set_jupyter_format('png')
# set high resolution of graphviz output
graphviz.engine.DOT().format = 'png:cairo:cairo'
# Out:
# 'svg'

# %%
from torchview import draw_graph

model_graph = draw_graph(model, input_size=(1, 3, 32, 32),
                        graph_name='Cifar10CnnModel-v2',
                        hide_inner_tensors=True,
                        hide_module_functions=True,
                        graph_dir='BT',
                        save_graph=True)

model_graph.visual_graph
# Out:
# (dot.exe:3840): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.
#
# (dot.exe:36340): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.
